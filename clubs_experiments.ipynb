# %%
import random

import clubs

config = clubs.configs.NO_LIMIT_HOLDEM_SIX_PLAYER
dealer = clubs.poker.Dealer(**config)
obs = dealer.reset()

while True:
    call = obs['call']
    min_raise = obs['min_raise']
    max_raise = obs['max_raise']

    rand = random.random()
    if rand < 0.1:
        bet = 0
    elif rand < 0.80:
        bet = call
    else:
        bet = random.randint(min_raise, max_raise)

    obs, rewards, done = dealer.step(bet)
    if all(done):
        break

print(rewards)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import random
# ----> 3 import clubs
#       5 config = clubs.configs.NO_LIMIT_HOLDEM_SIX_PLAYER
#       6 dealer = clubs.poker.Dealer(**config)
#
# File c:\Python\Lib\site-packages\clubs\__init__.py:23
#      21     pass  # pragma: no cover
#      22 else:
# ---> 23     from . import configs, poker, render
#      24     from .poker import Card, Dealer, Deck, Evaluator, LookupTable
#      26 __all__ = [
#      27     "configs",
#      28     "poker",
#    (...)     34     "LookupTable",
#      35 ]
#
# File c:\Python\Lib\site-packages\clubs\poker\__init__.py:2
#       1 from .card import Card, Deck
# ----> 2 from .engine import Dealer
#       3 from .evaluator import Evaluator, LookupTable
#       5 __all__ = ["Card", "Dealer", "Deck", "Evaluator", "LookupTable"]
#
# File c:\Python\Lib\site-packages\clubs\poker\engine.py:12
#       9 else:
#      10     from typing_extensions import TypedDict, Literal
# ---> 12 from clubs import error, poker, render
#      15 class ObservationDict(TypedDict):
#      16     action: int
#
# File c:\Python\Lib\site-packages\clubs\render\__init__.py:2
#       1 from .ascii_viewer import ASCIIViewer
# ----> 2 from .graphic import GraphicViewer
#       3 from .viewer import PokerViewer
#       5 __all__ = ["ASCIIViewer", "GraphicViewer", "PokerViewer"]
#
# File c:\Python\Lib\site-packages\clubs\render\graphic.py:3
#       1 import copy
#       2 import http.client
# ----> 3 import imp
#       4 import math
#       5 import multiprocessing
#
# ModuleNotFoundError: No module named 'imp'

# %%
import gym

import clubs_gym

env = gym.make("KuhnTwoPlayer-v0")
env.register_agents([clubs_gym.agent.kuhn.NashKuhnAgent(0.3)] * 2)
obs = env.reset()

while True:
    bet = env.act(obs)
    obs, rewards, done, info = env.step(bet)

    if all(done):
        break

print(rewards)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 3
#       1 import gym
# ----> 3 import clubs_gym
#       5 env = gym.make("KuhnTwoPlayer-v0")
#       6 env.register_agents([clubs_gym.agent.kuhn.NashKuhnAgent(0.3)] * 2)
#
# File c:\Python\Lib\site-packages\clubs_gym\__init__.py:22
#      20     pass
#      21 else:
# ---> 22     from . import agent, envs
#      24 from typing import Dict
#      26 import clubs
#
# File c:\Python\Lib\site-packages\clubs_gym\agent\__init__.py:1
# ----> 1 from . import base, kuhn
#       2 from .base import BaseAgent
#       4 __all__ = ["base", "BaseAgent", "kuhn"]
#
# File c:\Python\Lib\site-packages\clubs_gym\agent\base.py:1
# ----> 1 import clubs
#       4 class BaseAgent:
#       5     def __init__(self) -> None:
#
# File c:\Python\Lib\site-packages\clubs\__init__.py:23
#      21     pass  # pragma: no cover
#      22 else:
# ---> 23     from . import configs, poker, render
#      24     from .poker import Card, Dealer, Deck, Evaluator, LookupTable
#      26 __all__ = [
#      27     "configs",
#      28     "poker",
#    (...)     34     "LookupTable",
#      35 ]
#
# File c:\Python\Lib\site-packages\clubs\poker\__init__.py:2
#       1 from .card import Card, Deck
# ----> 2 from .engine import Dealer
#       3 from .evaluator import Evaluator, LookupTable
#       5 __all__ = ["Card", "Dealer", "Deck", "Evaluator", "LookupTable"]
#
# File c:\Python\Lib\site-packages\clubs\poker\engine.py:12
#       9 else:
#      10     from typing_extensions import TypedDict, Literal
# ---> 12 from clubs import error, poker, render
#      15 class ObservationDict(TypedDict):
#      16     action: int
#
# File c:\Python\Lib\site-packages\clubs\render\__init__.py:2
#       1 from .ascii_viewer import ASCIIViewer
# ----> 2 from .graphic import GraphicViewer
#       3 from .viewer import PokerViewer
#       5 __all__ = ["ASCIIViewer", "GraphicViewer", "PokerViewer"]
#
# File c:\Python\Lib\site-packages\clubs\render\graphic.py:3
#       1 import copy
#       2 import http.client
# ----> 3 import imp
#       4 import math
#       5 import multiprocessing
#
# ModuleNotFoundError: No module named 'imp'
