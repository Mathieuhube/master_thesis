# %%
import clubs
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import clubs
#
# File c:\Users\mathi\miniconda3\Lib\site-packages\clubs\__init__.py:23
#      21     pass  # pragma: no cover
#      22 else:
# ---> 23     from . import configs, poker, render
#      24     from .poker import Card, Dealer, Deck, Evaluator, LookupTable
#      26 __all__ = [
#      27     "configs",
#      28     "poker",
#    (...)
#      34     "LookupTable",
#      35 ]
#
# ImportError: cannot import name 'configs' from partially initialized module 'clubs' (most likely due to a circular import) (c:\Users\mathi\miniconda3\Lib\site-packages\clubs\__init__.py)

# %%
import random

import clubs

config = clubs.configs.NO_LIMIT_HOLDEM_SIX_PLAYER
dealer = clubs.poker.Dealer(**config)
obs = dealer.reset()

while True:
    call = obs['call']
    min_raise = obs['min_raise']
    max_raise = obs['max_raise']

    rand = random.random()
    if rand < 0.1:
        bet = 0
    elif rand < 0.80:
        bet = call
    else:
        bet = random.randint(min_raise, max_raise)

    obs, rewards, done = dealer.step(bet)
    if all(done):
        break

print(rewards)

# %%
import gym

import clubs_gym

env = gym.make("KuhnTwoPlayer-v0")
env.register_agents([clubs_gym.agent.kuhn.NashKuhnAgent(0.3)] * 2)
obs = env.reset()

while True:
    bet = env.act(obs)
    obs, rewards, done, info = env.step(bet)

    if all(done):
        break

print(rewards)
