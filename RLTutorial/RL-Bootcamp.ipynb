# %%
import os
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from pyvirtualdisplay import Display
import numpy

# %%
environment_name = 'CartPole-v1'
env = gym.make(environment_name, render_mode='human')

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])  # Wrap the environment in a DummyVecEnv
model = PPO('MlpPolicy', env, verbose=1)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 2228 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1559       |
# |    iterations           | 2          |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.00977497 |
# |    clip_fraction        | 0.102      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.686     |
# |    explained_variance   | 0.00291    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.11       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0165    |
# |    value_loss           | 54.4       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1426        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009701448 |
# |    clip_fraction        | 0.0541      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.666      |
# |    explained_variance   | 0.0696      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.6         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 34.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1381        |
# |    iterations           | 4           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008065596 |
# |    clip_fraction        | 0.0762      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.638      |
# |    explained_variance   | 0.221       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.3        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0165     |
# |    value_loss           | 54.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1351        |
# |    iterations           | 5           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009687547 |
# |    clip_fraction        | 0.0759      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.607      |
# |    explained_variance   | 0.392       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18          |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.016      |
# |    value_loss           | 53.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1331        |
# |    iterations           | 6           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010424528 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.592      |
# |    explained_variance   | 0.644       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.3        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.016      |
# |    value_loss           | 44.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1311        |
# |    iterations           | 7           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.011538312 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.579      |
# |    explained_variance   | 0.616       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27          |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0195     |
# |    value_loss           | 52.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1309        |
# |    iterations           | 8           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006429307 |
# |    clip_fraction        | 0.0629      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.571      |
# |    explained_variance   | 0.609       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.9        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 49.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1307        |
# |    iterations           | 9           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008993318 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.58       |
# |    explained_variance   | 0.911       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.2         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0142     |
# |    value_loss           | 21.6        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1302       |
# |    iterations           | 10         |
# |    time_elapsed         | 15         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.00802819 |
# |    clip_fraction        | 0.0613     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.57      |
# |    explained_variance   | 0.867      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.57       |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.00616   |
# |    value_loss           | 27.8       |
# ----------------------------------------

# %%
episodes = 10

#display = Display(visible=0, size=(1400, 900))
#display.start()

for episode in range(1, episodes+1):
    obs = env.reset()
    done = False
    score = 0
     
    while not done:
        env.render()
        action, _  = model.predict(obs)
        obs, reward, done, info = env.step(action)
        score += reward
    print(f'Episode: {episode}, Score: {score}')
env.close()
# Out:
# c:\Python\Lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:259: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# Episode: 1, Score: [500.]
# Episode: 2, Score: [500.]
# Episode: 3, Score: [175.]
# Episode: 4, Score: [433.]
# Episode: 5, Score: [500.]
# Episode: 6, Score: [500.]
# Episode: 7, Score: [377.]
# Episode: 8, Score: [500.]
# Episode: 9, Score: [500.]
# Episode: 10, Score: [500.]
