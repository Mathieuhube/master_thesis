# %%
#modeling file
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import (accuracy_score, precision_score, recall_score,
                             f1_score, roc_auc_score, confusion_matrix,
                             roc_curve, precision_recall_curve)
from sklearn.utils import class_weight
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as imbpipeline
from sklearn.pipeline import Pipeline

# Set random seed for reproducibility
RANDOM_STATE = 1234

# %%
# Load data
data = pd.read_csv('./thesis_data.csv')

# %%
data.columns
# Out:
# Index(['room', 'game', 'hand', 'won', 'player0_preflop_fold',
#        'player0_flop_fold', 'player0_turn_fold', 'player0_river_fold',
#        'player0_bet', 'player0_preflop_bet', 'player0_flop_bet',
#        'player0_turn_bet', 'player0_river_bet', 'opponent_preflop_bets',
#        'opponent_flop_bets', 'opponent_turn_bets', 'opponent_river_bets',
#        'opponent_bet', 'starthandstrategy', 'flop_hand', 'turn_hand',
#        'river_hand'],
#       dtype='object')

# %%
df_encoded = pd.get_dummies(data, columns=['starthandstrategy'])
df_encoded = pd.get_dummies(df_encoded, columns=['flop_hand'])
df_encoded = pd.get_dummies(df_encoded, columns=['turn_hand'])
df_encoded = pd.get_dummies(df_encoded, columns=['river_hand'])
df_encoded.columns
# Out:
# Index(['room', 'game', 'hand', 'won', 'player0_preflop_fold',
#        'player0_flop_fold', 'player0_turn_fold', 'player0_river_fold',
#        'player0_bet', 'player0_preflop_bet', 'player0_flop_bet',
#        'player0_turn_bet', 'player0_river_bet', 'opponent_preflop_bets',
#        'opponent_flop_bets', 'opponent_turn_bets', 'opponent_river_bets',
#        'opponent_bet', 'starthandstrategy_3-Bet', 'starthandstrategy_4-Bet',
#        'starthandstrategy_Call', 'starthandstrategy_Fold', 'flop_hand_Flush',
#        'flop_hand_Four of a Kind', 'flop_hand_Full House',
#        'flop_hand_High Card', 'flop_hand_Pair', 'flop_hand_Straight',
#        'flop_hand_Three of a Kind', 'flop_hand_Two Pair', 'turn_hand_Flush',
#        'turn_hand_Four of a Kind', 'turn_hand_Full House',
#        'turn_hand_High Card', 'turn_hand_Pair', 'turn_hand_Straight',
#        'turn_hand_Three of a Kind', 'turn_hand_Two Pair', 'river_hand_Flush',
#        'river_hand_Four of a Kind', 'river_hand_Full House',
#        'river_hand_High Card', 'river_hand_Pair', 'river_hand_Straight',
#        'river_hand_Three of a Kind', 'river_hand_Two Pair'],
#       dtype='object')

# %%
# 1. Data Preparation Function
def prepare_stage_data(data, stage_features, target_column, previous_target=None):
    """
    Prepare data for a specific game stage
    """
    if previous_target:
        # Filter out players who folded in previous stages
        stage_data = data[data[previous_target] == 0].copy()
    else:
        stage_data = data.copy()

    X = stage_data[stage_features]
    y = stage_data[target_column]

    # Check class imbalance
    class_ratio = y.value_counts(normalize=True)
    print(f"Class distribution: {class_ratio.to_dict()}")

    return X, y

# %%
# 2. Model Training and Evaluation Function
def train_evaluate_model(X_train, X_test, y_train, y_test, model, model_name, stage_name):
    """
    Train, evaluate, and visualize model performance
    """
    # Train model
    model.fit(X_train, y_train)

    # Predictions
    y_pred = model.predict(X_test)
    y_proba = model.predict_proba(X_test)[:, 1]

    # Calculate metrics
    metrics = {
        'accuracy': accuracy_score(y_test, y_pred),
        'precision': precision_score(y_test, y_pred),
        'recall': recall_score(y_test, y_pred),
        'f1': f1_score(y_test, y_pred),
        'roc_auc': roc_auc_score(y_test, y_proba)
    }

    # Confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=['Not Fold', 'Fold'],
                yticklabels=['Not Fold', 'Fold'])
    plt.title(f'{model_name} - {stage_name} Confusion Matrix')
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.savefig(f'{model_name}_{stage_name}_confusion_matrix.png', bbox_inches='tight')
    plt.close()

    # ROC Curve
    fpr, tpr, _ = roc_curve(y_test, y_proba)
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, label=f'{model_name} (AUC = {metrics["roc_auc"]:.2f})')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'{model_name} - {stage_name} ROC Curve')
    plt.legend()
    plt.savefig(f'{model_name}_{stage_name}_roc_curve.png', bbox_inches='tight')
    plt.close()

    # Precision-Recall Curve
    precision, recall, _ = precision_recall_curve(y_test, y_proba)
    plt.figure(figsize=(8, 6))
    plt.plot(recall, precision, label=f'{model_name}')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title(f'{model_name} - {stage_name} Precision-Recall Curve')
    plt.legend()
    plt.savefig(f'{model_name}_{stage_name}_pr_curve.png', bbox_inches='tight')
    plt.close()

    return metrics, model

# %%
# 3. Feature Importance Analysis
def plot_feature_importance(model, feature_names, model_name, stage_name, top_n=20):
    """
    Plot feature importance for tree-based models
    """
    if hasattr(model, 'feature_importances_'):
        importances = model.feature_importances_
        indices = np.argsort(importances)[-top_n:]

        plt.figure(figsize=(10, 8))
        plt.title(f'{model_name} - {stage_name} Feature Importance')
        plt.barh(range(len(indices)), importances[indices], align='center')
        plt.yticks(range(len(indices)), [feature_names[i] for i in indices])
        plt.xlabel('Relative Importance')
        plt.tight_layout()
        plt.savefig(f'{model_name}_{stage_name}_feature_importance.png', bbox_inches='tight')
        plt.close()

        # Return top features
        return pd.Series(importances, index=feature_names).sort_values(ascending=False).head(top_n)
    return None

# %%
# 4. Hyperparameter Tuning with Class Weight Handling
def tune_model(X_train, y_train, model_type='rf'):
    """
    Hyperparameter tuning with handling for class imbalance
    """
    # Calculate class weights
    classes = np.unique(y_train)
    weights = class_weight.compute_class_weight('balanced', classes=classes, y=y_train)
    class_weights = dict(zip(classes, weights))

    if model_type == 'lr':
        # Logistic Regression pipeline with scaling
        pipeline = Pipeline([
            ('scaler', StandardScaler()),
            ('clf', LogisticRegression(random_state=RANDOM_STATE, max_iter=1000))
        ])

        param_grid = {
            'clf__C': [0.001, 0.01, 0.1, 1, 10, 100],
            'clf__penalty': ['l1', 'l2'],
            'clf__solver': ['liblinear'],
            'clf__class_weight': [None, class_weights]
        }

    elif model_type == 'rf':
        pipeline = RandomForestClassifier(random_state=RANDOM_STATE)
        param_grid = {
            'n_estimators': [100, 200],
            'max_depth': [10, 20, 30, None],
            'min_samples_split': [2, 5, 10],
            'min_samples_leaf': [1, 2, 4],
            'class_weight': [None, 'balanced', class_weights]
        }

    elif model_type == 'gb':
        pipeline = GradientBoostingClassifier(random_state=RANDOM_STATE)
        param_grid = {
            'n_estimators': [100, 200],
            'learning_rate': [0.01, 0.1],
            'max_depth': [3, 5, 7],
            'subsample': [0.8, 1.0]
        }

    # Use stratified K-Fold for imbalanced data
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)
    grid_search = GridSearchCV(
        estimator=pipeline,
        param_grid=param_grid,
        cv=cv,
        scoring='roc_auc',
        n_jobs=-1,
        verbose=1
    )

    grid_search.fit(X_train, y_train)

    print(f"Best parameters: {grid_search.best_params_}")
    print(f"Best ROC AUC: {grid_search.best_score_:.4f}")

    return grid_search.best_estimator_

# %%
# 5. Handle Class Imbalance
def balance_data(X_train, y_train, method='smote'):
    """
    Handle class imbalance using different techniques
    """
    if method == 'smote':
        smote = SMOTE(random_state=RANDOM_STATE)
        X_res, y_res = smote.fit_resample(X_train, y_train)
    elif method == 'class_weight':
        return X_train, y_train  # Weights handled in model
    else:
        # Random oversampling
        from imblearn.over_sampling import RandomOverSampler
        ros = RandomOverSampler(random_state=RANDOM_STATE)
        X_res, y_res = ros.fit_resample(X_train, y_train)

    return X_res, y_res

# %%
# =============== MAIN EXECUTION ===============

allfeatures = ['room', 'game', 'hand', 'won', 'player0_preflop_fold',
       'player0_flop_fold', 'player0_turn_fold', 'player0_river_fold',
       'player0_bet', 'player0_preflop_bet', 'player0_flop_bet',
       'player0_turn_bet', 'player0_river_bet', 'opponent_preflop_bets',
       'opponent_flop_bets', 'opponent_turn_bets', 'opponent_river_bets',
       'opponent_bet', 'starthandstrategy_3-Bet', 'starthandstrategy_4-Bet',
       'starthandstrategy_Call', 'starthandstrategy_Fold', 'flop_hand_Flush',
       'flop_hand_Four of a Kind', 'flop_hand_Full House',
       'flop_hand_High Card', 'flop_hand_Pair', 'flop_hand_Straight',
       'flop_hand_Three of a Kind', 'flop_hand_Two Pair', 'turn_hand_Flush',
       'turn_hand_Four of a Kind', 'turn_hand_Full House',
       'turn_hand_High Card', 'turn_hand_Pair', 'turn_hand_Straight',
       'turn_hand_Three of a Kind', 'turn_hand_Two Pair', 'river_hand_Flush',
       'river_hand_Four of a Kind', 'river_hand_Full House',
       'river_hand_High Card', 'river_hand_Pair', 'river_hand_Straight',
       'river_hand_Three of a Kind', 'river_hand_Two Pair']

# Define features for each stage
preflop_features = ['player0_preflop_bet', 'opponent_preflop_bets', 
                    'starthandstrategy_3-Bet', 'starthandstrategy_4-Bet',
                    'starthandstrategy_Call', 'starthandstrategy_Fold']  
flop_features = ['player0_preflop_bet', 'opponent_preflop_bets', 
                    'starthandstrategy_3-Bet', 'starthandstrategy_4-Bet',
                    'starthandstrategy_Call', 'starthandstrategy_Fold',
                    'player0_flop_bet', 'opponent_flop_bets',
                    'flop_hand_Flush', 'flop_hand_Four of a Kind',
                    'flop_hand_Full House', 'flop_hand_High Card',
                    'flop_hand_Pair', 'flop_hand_Straight',
                    'flop_hand_Three of a Kind', 'flop_hand_Two Pair']       
turn_features = ['player0_preflop_bet', 'opponent_preflop_bets', 
                    'starthandstrategy_3-Bet', 'starthandstrategy_4-Bet',
                    'starthandstrategy_Call', 'starthandstrategy_Fold',
                    'player0_flop_bet', 'opponent_flop_bets',
                    'flop_hand_Flush', 'flop_hand_Four of a Kind',
                    'flop_hand_Full House', 'flop_hand_High Card',
                    'flop_hand_Pair', 'flop_hand_Straight',
                    'flop_hand_Three of a Kind', 'flop_hand_Two Pair',
                    'player0_turn_bet', 'opponent_turn_bets',
                    'turn_hand_Flush', 'turn_hand_Four of a Kind',
                    'turn_hand_Full House', 'turn_hand_High Card',
                    'turn_hand_Pair', 'turn_hand_Straight',
                    'turn_hand_Three of a Kind', 'turn_hand_Two Pair']      
river_features = ['player0_preflop_bet', 'opponent_preflop_bets', 
                    'starthandstrategy_3-Bet', 'starthandstrategy_4-Bet',
                    'starthandstrategy_Call', 'starthandstrategy_Fold',
                    'player0_flop_bet', 'opponent_flop_bets',
                    'flop_hand_Flush', 'flop_hand_Four of a Kind',
                    'flop_hand_Full House', 'flop_hand_High Card',
                    'flop_hand_Pair', 'flop_hand_Straight',
                    'flop_hand_Three of a Kind', 'flop_hand_Two Pair',
                    'player0_turn_bet', 'opponent_turn_bets',
                    'turn_hand_Flush', 'turn_hand_Four of a Kind',
                    'turn_hand_Full House', 'turn_hand_High Card',
                    'turn_hand_Pair', 'turn_hand_Straight',
                    'turn_hand_Three of a Kind', 'turn_hand_Two Pair',
                    'player0_river_bet', 'opponent_river_bets',
                    'river_hand_Flush', 'river_hand_Four of a Kind',
                    'river_hand_Full House', 'river_hand_High Card',
                    'river_hand_Pair', 'river_hand_Straight',
                    'river_hand_Three of a Kind', 'river_hand_Two Pair']  

stages = [
    {'name': 'Pre-flop', 'features': preflop_features,
     'target': 'player0_preflop_fold', 'previous_target': None},

    {'name': 'Flop', 'features': flop_features,
     'target': 'player0_flop_fold', 'previous_target': 'player0_preflop_fold'},

    {'name': 'Turn', 'features': turn_features,
     'target': 'player0_turn_fold', 'previous_target': 'player0_flop_fold'},

    {'name': 'River', 'features': river_features,
     'target': 'player0_river_fold', 'previous_target': 'player0_turn_fold'}
]

# Models to compare
models = {
    'Logistic Regression': LogisticRegression(random_state=RANDOM_STATE, max_iter=1000),
    'Random Forest': RandomForestClassifier(random_state=RANDOM_STATE),
    'Gradient Boosting': GradientBoostingClassifier(random_state=RANDOM_STATE)
}

# NCI: Features

# %%
# Store results
results = {}

for stage in stages:
    print(f"\n{'='*50}")
    print(f"PROCESSING STAGE: {stage['name']}")
    print(f"{'='*50}")

    # Prepare data
    X, y = prepare_stage_data(
        df_encoded,
        stage['features'],
        stage['target'],
        stage['previous_target']
    )

    # Train-test split (stratified for class imbalance)
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.2, stratify=y, random_state=RANDOM_STATE
    )

    # Handle class imbalance
    
    X_train_bal, y_train_bal = balance_data(X_train, y_train, method='smote')

    stage_results = {}

    for model_name, model in models.items():
        print(f"\nTraining {model_name} for {stage['name']}")

        # Hyperparameter tuning
        model_type = 'lr' if 'Logistic' in model_name else 'rf' if 'Random' in model_name else 'gb'
        tuned_model = tune_model(X_train_bal, y_train_bal, model_type)

        # Train and evaluate
        metrics, trained_model = train_evaluate_model(
            X_train_bal, X_test, y_train_bal, y_test,
            tuned_model, model_name, stage['name']
        )

        # Store metrics
        stage_results[model_name] = metrics

        # Feature importance for tree-based models
        if 'Forest' in model_name or 'Boosting' in model_name:
            feature_imp = plot_feature_importance(
                trained_model, X.columns, model_name, stage['name']
            )
            print(f"\nTop features for {model_name} at {stage['name']}:\n{feature_imp}")

    results[stage['name']] = stage_results
# Out:
# ==================================================
# PROCESSING STAGE: Pre-flop
# ==================================================
# Class distribution: {0: 0.9175642087821044, 1: 0.08243579121789561}
#
# Training Logistic Regression for Pre-flop
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Best parameters: {'clf__C': 1, 'clf__class_weight': None, 'clf__penalty': 'l1', 'clf__solver': 'liblinear'}
# Best ROC AUC: 0.9082
#
# Training Random Forest for Pre-flop
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# Best parameters: {'class_weight': None, 'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# Best ROC AUC: 0.9868
#
# Top features for Random Forest at Pre-flop:
# opponent_preflop_bets      0.683973
# player0_preflop_bet        0.233460
# starthandstrategy_Fold     0.025979
# starthandstrategy_4-Bet    0.022101
# starthandstrategy_Call     0.021921
# starthandstrategy_3-Bet    0.012566
# dtype: float64
#
# Training Gradient Boosting for Pre-flop
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Best parameters: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200, 'subsample': 1.0}
# Best ROC AUC: 0.9875
#
# Top features for Gradient Boosting at Pre-flop:
# opponent_preflop_bets      0.685318
# player0_preflop_bet        0.289408
# starthandstrategy_Fold     0.008586
# starthandstrategy_Call     0.006303
# starthandstrategy_4-Bet    0.005217
# starthandstrategy_3-Bet    0.005168
# dtype: float64
#
# ==================================================
# PROCESSING STAGE: Flop
# ==================================================
# Class distribution: {0: 0.8497516930022574, 1: 0.15024830699774266}
#
# Training Logistic Regression for Flop
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Best parameters: {'clf__C': 10, 'clf__class_weight': None, 'clf__penalty': 'l2', 'clf__solver': 'liblinear'}
# Best ROC AUC: 0.9955
#
# Training Random Forest for Flop
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# Best parameters: {'class_weight': 'balanced', 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# Best ROC AUC: 0.9990
#
# Top features for Random Forest at Flop:
# opponent_flop_bets           0.309210
# player0_flop_bet             0.281732
# opponent_preflop_bets        0.137399
# flop_hand_High Card          0.096381
# player0_preflop_bet          0.086828
# flop_hand_Pair               0.038790
# starthandstrategy_Call       0.018103
# starthandstrategy_Fold       0.012671
# starthandstrategy_4-Bet      0.005767
# starthandstrategy_3-Bet      0.005190
# flop_hand_Two Pair           0.004821
# flop_hand_Three of a Kind    0.002620
# flop_hand_Straight           0.000277
# flop_hand_Flush              0.000131
# flop_hand_Full House         0.000077
# flop_hand_Four of a Kind     0.000001
# dtype: float64
#
# Training Gradient Boosting for Flop
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Best parameters: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200, 'subsample': 0.8}
# Best ROC AUC: 0.9994
#
# Top features for Gradient Boosting at Flop:
# player0_flop_bet             2.925264e-01
# opponent_flop_bets           2.613548e-01
# opponent_preflop_bets        1.476739e-01
# flop_hand_High Card          1.469906e-01
# flop_hand_Pair               1.055614e-01
# player0_preflop_bet          3.438156e-02
# starthandstrategy_Call       4.484129e-03
# starthandstrategy_3-Bet      2.208515e-03
# starthandstrategy_Fold       2.076650e-03
# flop_hand_Two Pair           2.002692e-03
# starthandstrategy_4-Bet      5.378249e-04
# flop_hand_Three of a Kind    1.932519e-04
# flop_hand_Straight           7.297777e-06
# flop_hand_Full House         7.863441e-07
# flop_hand_Flush              1.274848e-07
# flop_hand_Four of a Kind     0.000000e+00
# dtype: float64
#
# ==================================================
# PROCESSING STAGE: Turn
# ==================================================
# Class distribution: {0: 0.914472419757832, 1: 0.08552758024216799}
#
# Training Logistic Regression for Turn
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Best parameters: {'clf__C': 100, 'clf__class_weight': None, 'clf__penalty': 'l1', 'clf__solver': 'liblinear'}
# Best ROC AUC: 0.9947
#
# Training Random Forest for Turn
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# Best parameters: {'class_weight': None, 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Best ROC AUC: 0.9991
#
# Top features for Random Forest at Turn:
# opponent_turn_bets           0.176083
# player0_turn_bet             0.159111
# turn_hand_Pair               0.114482
# flop_hand_High Card          0.095108
# turn_hand_High Card          0.094449
# opponent_preflop_bets        0.078484
# opponent_flop_bets           0.077225
# player0_flop_bet             0.054577
# player0_preflop_bet          0.051235
# flop_hand_Pair               0.033893
# starthandstrategy_Call       0.016820
# starthandstrategy_Fold       0.015195
# turn_hand_Two Pair           0.012001
# starthandstrategy_3-Bet      0.007441
# flop_hand_Two Pair           0.005898
# starthandstrategy_4-Bet      0.003338
# turn_hand_Three of a Kind    0.001832
# flop_hand_Three of a Kind    0.001051
# turn_hand_Straight           0.001007
# turn_hand_Flush              0.000565
# dtype: float64
#
# Training Gradient Boosting for Turn
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Best parameters: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200, 'subsample': 0.8}
# Best ROC AUC: 0.9997
#
# Top features for Gradient Boosting at Turn:
# flop_hand_High Card          0.206602
# player0_turn_bet             0.203550
# turn_hand_Pair               0.197779
# opponent_turn_bets           0.182371
# opponent_flop_bets           0.077395
# flop_hand_Pair               0.045365
# opponent_preflop_bets        0.031356
# turn_hand_Two Pair           0.019306
# turn_hand_High Card          0.011094
# player0_flop_bet             0.008171
# player0_preflop_bet          0.006020
# starthandstrategy_Call       0.003144
# starthandstrategy_3-Bet      0.003041
# starthandstrategy_Fold       0.001515
# flop_hand_Two Pair           0.001018
# turn_hand_Three of a Kind    0.000769
# starthandstrategy_4-Bet      0.000637
# flop_hand_Three of a Kind    0.000569
# turn_hand_Straight           0.000283
# turn_hand_Flush              0.000011
# dtype: float64
#
# ==================================================
# PROCESSING STAGE: River
# ==================================================
# Class distribution: {0: 0.9442754919499106, 1: 0.055724508050089445}
#
# Training Logistic Regression for River
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Best parameters: {'clf__C': 100, 'clf__class_weight': None, 'clf__penalty': 'l1', 'clf__solver': 'liblinear'}
# Best ROC AUC: 0.9966
#
# Training Random Forest for River
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# Best parameters: {'class_weight': 'balanced', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# Best ROC AUC: 0.9985
#
# Top features for Random Forest at River:
# river_hand_Pair              0.175530
# turn_hand_High Card          0.099759
# turn_hand_Pair               0.099676
# river_hand_High Card         0.078768
# opponent_river_bets          0.073080
# player0_river_bet            0.067246
# flop_hand_High Card          0.058854
# opponent_preflop_bets        0.040510
# player0_turn_bet             0.039289
# opponent_flop_bets           0.039094
# opponent_turn_bets           0.038066
# player0_preflop_bet          0.031624
# flop_hand_Pair               0.031180
# river_hand_Two Pair          0.029048
# player0_flop_bet             0.025979
# starthandstrategy_Call       0.017176
# starthandstrategy_Fold       0.016586
# turn_hand_Two Pair           0.013638
# flop_hand_Two Pair           0.006111
# turn_hand_Three of a Kind    0.004275
# dtype: float64
#
# Training Gradient Boosting for River
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Best parameters: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200, 'subsample': 0.8}
# Best ROC AUC: 0.9998
#
# Top features for Gradient Boosting at River:
# river_hand_Pair               0.397102
# river_hand_High Card          0.210066
# player0_river_bet             0.091112
# opponent_river_bets           0.078887
# river_hand_Two Pair           0.061586
# opponent_flop_bets            0.020263
# opponent_turn_bets            0.020071
# starthandstrategy_Call        0.017331
# player0_turn_bet              0.013198
# starthandstrategy_Fold        0.012871
# opponent_preflop_bets         0.012719
# player0_preflop_bet           0.011512
# flop_hand_High Card           0.010431
# flop_hand_Pair                0.008147
# turn_hand_High Card           0.005722
# turn_hand_Pair                0.005365
# turn_hand_Three of a Kind     0.004990
# flop_hand_Two Pair            0.004758
# player0_flop_bet              0.004180
# river_hand_Three of a Kind    0.002615
# dtype: float64

# %%
# Print final results
print("\n\nFINAL RESULTS:")
for stage, stage_models in results.items():
    print(f"\n{stage} Stage:")
    for model_name, metrics in stage_models.items():
        print(f"{model_name}:")
        print(f"  Accuracy: {metrics['accuracy']:.4f}")
        print(f"  Precision: {metrics['precision']:.4f}")
        print(f"  Recall: {metrics['recall']:.4f}")
        print(f"  F1-Score: {metrics['f1']:.4f}")
        print(f"  ROC AUC: {metrics['roc_auc']:.4f}")

# Save results to CSV
results_df = pd.DataFrame.from_dict({(i,j): results[i][j]
                                   for i in results.keys()
                                   for j in results[i].keys()},
                                  orient='index')
results_df.to_csv('model_results.csv')
# Out:
# FINAL RESULTS:
#
# Pre-flop Stage:
# Logistic Regression:
#   Accuracy: 0.9416
#   Precision: 0.6066
#   Recall: 0.8291
#   F1-Score: 0.7006
#   ROC AUC: 0.8971
# Random Forest:
#   Accuracy: 0.9689
#   Precision: 0.7981
#   Recall: 0.8342
#   F1-Score: 0.8157
#   ROC AUC: 0.9658
# Gradient Boosting:
#   Accuracy: 0.9685
#   Precision: 0.7943
#   Recall: 0.8342
#   F1-Score: 0.8137
#   ROC AUC: 0.9701
#
# Flop Stage:
# Logistic Regression:
#   Accuracy: 0.9779
#   Precision: 0.8966
#   Recall: 0.9640
#   F1-Score: 0.9291
#   ROC AUC: 0.9890
# Random Forest:
#   Accuracy: 0.9779
#   Precision: 0.9494
#   Recall: 0.9009
#   F1-Score: 0.9245
#   ROC AUC: 0.9926
# Gradient Boosting:
#   Accuracy: 0.9932
#   Precision: 0.9818
#   Recall: 0.9730
#   F1-Score: 0.9774
#   ROC AUC: 0.9956
#
# Turn Stage:
# Logistic Regression:
#   Accuracy: 0.9457
#   Precision: 0.6245
#   Recall: 0.9157
#   F1-Score: 0.7426
#   ROC AUC: 0.9798
# Random Forest:
#   Accuracy: 0.9721
#   Precision: 0.9054
#   Recall: 0.7528
#   F1-Score: 0.8221
#   ROC AUC: 0.9743
# Gradient Boosting:
#   Accuracy: 0.9861
#   Precision: 0.9209
#   Recall: 0.9157
#   F1-Score: 0.9183
#   ROC AUC: 0.9963
#
# River Stage:
# Logistic Regression:
#   Accuracy: 0.9513
#   Precision: 0.5404
#   Recall: 0.8560
#   F1-Score: 0.6625
#   ROC AUC: 0.9791
# Random Forest:
#   Accuracy: 0.9521
#   Precision: 0.6023
#   Recall: 0.4240
#   F1-Score: 0.4977
#   ROC AUC: 0.9520
# Gradient Boosting:
#   Accuracy: 0.9848
#   Precision: 0.9099
#   Recall: 0.8080
#   F1-Score: 0.8559
#   ROC AUC: 0.9919

# %%
# Prepare data
X, y = prepare_stage_data(
    df_encoded,
    preflop_features,
    'player0_preflop_fold',
    None
)

# Train-test split (stratified for class imbalance)
X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.2, stratify=y, random_state=RANDOM_STATE
    )

    # Handle class imbalance
    
X_train_bal, y_train_bal = balance_data(X_train, y_train, method='smote')

stage_results = {}

for model_name, model in models.items():


        # Hyperparameter tuning
        model_type = 'lr' if 'Logistic' in model_name else 'rf' if 'Random' in model_name else 'gb'
        tuned_model = tune_model(X_train_bal, y_train_bal, model_type)

        # Train and evaluate
        metrics, trained_model = train_evaluate_model(
            X_train_bal, X_test, y_train_bal, y_test,
            tuned_model, model_name, 'Pre-flop'
        )

        # Store metrics
        stage_results[model_name] = metrics

        # Feature importance for tree-based models
        if 'Forest' in model_name or 'Boosting' in model_name:
            feature_imp = plot_feature_importance(
                trained_model, X.columns, model_name,'Pre-flop'
            )
# Out:
# Class distribution: {0: 0.9175642087821044, 1: 0.08243579121789561}
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Best parameters: {'clf__C': 1, 'clf__class_weight': None, 'clf__penalty': 'l1', 'clf__solver': 'liblinear'}
# Best ROC AUC: 0.9082
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# Best parameters: {'class_weight': None, 'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# Best ROC AUC: 0.9868
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Best parameters: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200, 'subsample': 1.0}
# Best ROC AUC: 0.9875

# %%
probs = trained_model.predict_proba(df_encoded[preflop_features])[:, 0]
rounded_probs = np.round(probs, 2)
df_encoded['Predicted_fold_prob'] = rounded_probs
df_encoded['irrational_call'] = np.where((df_encoded['player0_preflop_fold'] == 0) & (df_encoded['Predicted_fold_prob'] > 0.85), 1, 0)
df_encoded['Irrational_flop_calls_per_game'] = df_encoded.groupby('game')['irrational_call'].cumsum()
df_encoded['Hand_count_per_game'] = df_encoded.groupby('game').cumcount() + 1
df_encoded['Irrational_gambling_rate'] = df_encoded['Irrational_flop_calls_per_game'] / df_encoded['Hand_count_per_game']
df_encoded['NCI_Warning'] = np.where((df_encoded['Predicted_fold_prob'] > 0.85) & (df_encoded['irrational_call'] == 1) & (df_encoded['Irrational_gambling_rate'] > 0.8) & (df_encoded['Hand_count_per_game'] > 10), 'Stop Playing', 'Resume Playing')

# %%
print( "irrational play at: " + str(round(len(df_encoded[df_encoded['NCI_Warning'] == 'Stop Playing']['game'].unique()) / len(df_encoded['game'].unique()) * 100)) + "% of games")
# Out:
# irrational play at: 18% of games
